# %% [markdown]
# ## Pandas - модуль, призначений для обробки та аналізу даних на Python.
# ## Pandas побудований на основі іншої бібліотеки під назвою NumPy. Він використовує типи даних NumPy і можливо просто переходити між об'єктами обох бібліотек.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas працює з двома основними структурами даних: Series і DataFrame

# %% [markdown]
# ### Сприймайте Series як колонку з індексом
# ### У Series може бути визначений тип даних (атрибут dtype)

# %%
my_data = ['Adenosine', 'Thymine', 'Citosine', 'Guanine']

my_series_1 = pd.Series(my_data)

# %%
my_series_1
# Out:
# 0    Adenosine
# 1      Thymine
# 2     Citosine
# 3      Guanine
# dtype: object

# %%
type(my_series_1)
# Out:
# pandas.core.series.Series

# %%
my_other_data = [1, 2, 3, 4]

mah_series_2 = pd.Series(my_other_data)

# %%
mah_series_2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
my_other_data_2 = [1, 2, 3, 4.0]

mah_series_3 = pd.Series(my_other_data_2)

# %%
mah_series_3
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
mah_series_2 +  mah_series_3
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    8.0
# dtype: float64

# %%
mah_series_2**2
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# dtype: int64

# %%
mah_series_3 % 2
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# dtype: float64

# %% [markdown]
# ### Індекс може бути визначений окремим параметром і не обов'язково має бути послідовністю цілих чисел

# %%
s1 = pd.Series([1, 2], index=['A', 'B'], name = "s1")

# %%
s1
# Out:
# A    1
# B    2
# Name: s1, dtype: int64

# %%
s2 = pd.Series([3, 4], index=['A', 'B'], name='s2')

# %%
s2
# Out:
# A    3
# B    4
# Name: s2, dtype: int64

# %% [markdown]
# ## Ми можемо комбінувати Series різними способами

# %%
comb_1 = pd.concat([s1, s2])

# %%
comb_1
# Out:
# A    1
# B    2
# A    3
# B    4
# dtype: int64

# %%
type(comb_1)
# Out:
# pandas.core.series.Series

# %%
comb_2 = pd.concat([s1, s2], axis=1)

# %%
comb_2
# Out:
#    s1  s2
# A   1   3
# B   2   4

# %%
type(comb_2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### comb_2 - об'єкт типу DataFrame. DataFrame це "таблиця", де кожна колонка - це окрема Series. І ці Series об'єднані разом за спільним індексом

# %%
pd.concat([s1, mah_series_3], axis=1)
# Out:
#     s1    0
# A  1.0  NaN
# B  2.0  NaN
# 0  NaN  1.0
# 1  NaN  2.0
# 2  NaN  3.0
# 3  NaN  4.0

# %%
df = pd.concat([s1, mah_series_3], axis=1)

# %%
df.columns = ["c1", "c2"]

# %%
df
# Out:
#     c1   c2
# A  1.0  NaN
# B  2.0  NaN
# 0  NaN  1.0
# 1  NaN  2.0
# 2  NaN  3.0
# 3  NaN  4.0

# %% [markdown]
# ## В основному, звісно, ви будете працювати з DataFrame, отриманими в результаті читання тих чи інших файлів
# ## У Pandas є коннектори для читання великої кількості різних форматів файлів (csv, json, xlsx, xml, parquet, orc тощо)

# %%
# Отримаємо поточну директорію для більш гнучкого відкриття файлів
import os
import pathlib

cwd = pathlib.Path(os.getcwd())

# %%
diabetes_csv_path = cwd / "diabetes/diabetes_prediction_dataset.csv"

# %%
diabetes_df = pd.read_csv(diabetes_csv_path)

# %%
pd.read_csv(diabetes_csv_path, header=None)
# Out:
# /tmp/ipykernel_24806/1031492521.py:1: DtypeWarning: Columns (1,2,3,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(diabetes_csv_path, header=None)
#              0     1             2              3                4      5  \
# 0       gender   age  hypertension  heart_disease  smoking_history    bmi
# 1       Female  80.0             0              1            never  25.19
# 2       Female  54.0             0              0          No Info  27.32
# 3         Male  28.0             0              0            never  27.32
# 4       Female  36.0             0              0          current  23.45
# ...        ...   ...           ...            ...              ...    ...
# 99996   Female  80.0             0              0          No Info  27.32
# 99997   Female   2.0             0              0          No Info  17.37
# 99998     Male  66.0             0              0           former  27.83
# 99999   Female  24.0             0              0            never  35.42
# 100000  Female  57.0             0              0          current  22.43
#
#                   6                    7         8
# 0       HbA1c_level  blood_glucose_level  diabetes
# 1               6.6                  140         0
# 2               6.6                   80         0
# 3               5.7                  158         0
# 4               5.0                  155         0
# ...             ...                  ...       ...
# 99996           6.2                   90         0
# 99997           6.5                  100         0
# 99998           5.7                  155         0
# 99999           4.0                  100         0
# 100000          6.6                   90         0
#
# [100001 rows x 9 columns]

# %%
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# ### DataFrame можна фільтрувати доволі різним чином. Можна обирати тільки потрібні вам колонки, можна фільтрувати їх за значеннями певної колонки тощо

# %%
diabetes_df["gender"]
# Out:
# 0        Female
# 1        Female
# 2          Male
# 3        Female
# 4          Male
#           ...
# 99995    Female
# 99996    Female
# 99997      Male
# 99998    Female
# 99999    Female
# Name: gender, Length: 100000, dtype: object

# %%
diabetes_df[["gender", "age", "smoking_history"]]
# Out:
#        gender   age smoking_history
# 0      Female  80.0           never
# 1      Female  54.0         No Info
# 2        Male  28.0           never
# 3      Female  36.0         current
# 4        Male  76.0         current
# ...       ...   ...             ...
# 99995  Female  80.0         No Info
# 99996  Female   2.0         No Info
# 99997    Male  66.0          former
# 99998  Female  24.0           never
# 99999  Female  57.0         current
#
# [100000 rows x 3 columns]

# %%
diabetes_df[diabetes_df["gender"] == "Female"]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 3      Female  36.0             0              0         current  23.45
# 5      Female  20.0             0              0           never  27.32
# 6      Female  44.0             0              0           never  19.31
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 3              5.0                  155         0
# 5              6.6                   85         0
# 6              6.5                  200         1
# ...            ...                  ...       ...
# 99994          4.8                  145         0
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [58552 rows x 9 columns]

# %%
filtered_women_df = diabetes_df[(diabetes_df["gender"] == "Female") & (diabetes_df["hypertension"] != 0) & (diabetes_df["diabetes"] == 1)]

# %%
filtered_women_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 104    Female  80.0             1              0           never  27.32
# 350    Female  52.0             1              0           never  50.30
# 466    Female  79.0             1              0          former  27.32
# 531    Female  49.0             1              0     not current  36.93
# 727    Female  38.0             1              0     not current  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99739  Female  65.0             1              0           never  35.00
# 99792  Female  80.0             1              0           never  21.33
# 99845  Female  43.0             1              0           never  34.21
# 99935  Female  65.0             1              1           never  33.55
# 99962  Female  58.0             1              0           never  38.31
#
#        HbA1c_level  blood_glucose_level  diabetes
# 104            6.8                  280         1
# 350            6.6                  155         1
# 466            6.5                  159         1
# 531            8.8                  155         1
# 727            6.1                  160         1
# ...            ...                  ...       ...
# 99739          7.0                  145         1
# 99792          6.8                  240         1
# 99845          6.5                  160         1
# 99935          8.2                  140         1
# 99962          7.0                  200         1
#
# [1118 rows x 9 columns]

# %%
filtered_women_df.query("blood_glucose_level > 200")
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 104    Female  80.0             1              0           never  27.32
# 882    Female  75.0             1              0         No Info  27.32
# 1082   Female  53.0             1              0           never  41.76
# 1135   Female  62.0             1              1           never  43.16
# 1185   Female  71.0             1              0         No Info  42.44
# ...       ...   ...           ...            ...             ...    ...
# 98353  Female  76.0             1              0           never  38.59
# 99067  Female  73.0             1              0           never  45.65
# 99149  Female  54.0             1              0            ever  31.86
# 99537  Female  67.0             1              0            ever  34.30
# 99792  Female  80.0             1              0           never  21.33
#
#        HbA1c_level  blood_glucose_level  diabetes
# 104            6.8                  280         1
# 882            6.6                  240         1
# 1082           6.8                  300         1
# 1135           8.8                  280         1
# 1185           6.8                  220         1
# ...            ...                  ...       ...
# 98353          6.6                  300         1
# 99067          6.0                  240         1
# 99149          5.7                  280         1
# 99537          5.7                  300         1
# 99792          6.8                  240         1
#
# [437 rows x 9 columns]

# %% [markdown]
# ### Найголовніше призначення Pandas - EDA (exploratory data analysis). Отже, він може показати багато статистичних і метаданих про ваші дані

# %%
diabetes_df.head(20)
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  80.0             0              1           never  25.19
# 1   Female  54.0             0              0         No Info  27.32
# 2     Male  28.0             0              0           never  27.32
# 3   Female  36.0             0              0         current  23.45
# 4     Male  76.0             1              1         current  20.14
# 5   Female  20.0             0              0           never  27.32
# 6   Female  44.0             0              0           never  19.31
# 7   Female  79.0             0              0         No Info  23.86
# 8     Male  42.0             0              0           never  33.64
# 9   Female  32.0             0              0           never  27.32
# 10  Female  53.0             0              0           never  27.32
# 11  Female  54.0             0              0          former  54.70
# 12  Female  78.0             0              0          former  36.05
# 13  Female  67.0             0              0           never  25.69
# 14  Female  76.0             0              0         No Info  27.32
# 15    Male  78.0             0              0         No Info  27.32
# 16    Male  15.0             0              0           never  30.36
# 17  Female  42.0             0              0           never  24.48
# 18  Female  42.0             0              0         No Info  27.32
# 19    Male  37.0             0              0            ever  25.72
#
#     HbA1c_level  blood_glucose_level  diabetes
# 0           6.6                  140         0
# 1           6.6                   80         0
# 2           5.7                  158         0
# 3           5.0                  155         0
# 4           4.8                  155         0
# 5           6.6                   85         0
# 6           6.5                  200         1
# 7           5.7                   85         0
# 8           4.8                  145         0
# 9           5.0                  100         0
# 10          6.1                   85         0
# 11          6.0                  100         0
# 12          5.0                  130         0
# 13          5.8                  200         0
# 14          5.0                  160         0
# 15          6.6                  126         0
# 16          6.1                  200         0
# 17          5.7                  158         0
# 18          5.7                   80         0
# 19          3.5                  159         0

# %%
diabetes_df.tail(15)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99985    Male  25.0             0              0         No Info  27.32
# 99986  Female  63.0             0              0           never  29.01
# 99987  Female  23.0             0              0           never  17.87
# 99988    Male  19.0             0              0         No Info  25.75
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99991    Male  22.0             0              0         current  29.65
# 99992  Female  26.0             0              0           never  34.34
# 99993  Female  40.0             0              0           never  40.69
# 99994  Female  36.0             0              0         No Info  24.60
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99985          5.8                  145         0
# 99986          4.8                  145         0
# 99987          5.8                  100         0
# 99988          5.0                  145         0
# 99989          5.0                  158         0
# 99990          6.1                  100         0
# 99991          6.0                   80         0
# 99992          6.5                  160         0
# 99993          3.5                  155         0
# 99994          4.8                  145         0
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
diabetes_df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
diabetes_df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %% [markdown]
# ### В Pandas можливі операції з окремими рядками

# %%
diabetes_df.loc[0]
# Out:
# gender                 Female
# age                      80.0
# hypertension                0
# heart_disease               1
# smoking_history         never
# bmi                     25.19
# HbA1c_level               6.6
# blood_glucose_level       140
# diabetes                    0
# Name: 0, dtype: object

# %%
diabetes_df.iloc[10]
# Out:
# gender                 Female
# age                      53.0
# hypertension                0
# heart_disease               0
# smoking_history         never
# bmi                     27.32
# HbA1c_level               6.1
# blood_glucose_level        85
# diabetes                    0
# Name: 10, dtype: object

# %%
diabetes_df.loc[0] = diabetes_df.loc[1]

# %%
diabetes_df.head(3)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  54.0             0              0         No Info  27.32
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                   80         0
# 1          6.6                   80         0
# 2          5.7                  158         0

# %%
diabetes_df.loc[0:7, ["heart_disease", "bmi"]]
# Out:
#    heart_disease    bmi
# 0              0  27.32
# 1              0  27.32
# 2              0  27.32
# 3              0  23.45
# 4              1  20.14
# 5              0  27.32
# 6              0  19.31
# 7              0  23.86

# %% [markdown]
# ### Ви можете так само змінювати індекси у DataFrame як забажаєте

# %%
diabetes_df.set_index("smoking_history")
# Out:
#                  gender   age  hypertension  heart_disease    bmi  \
# smoking_history
# No Info          Female  54.0             0              0  27.32
# No Info          Female  54.0             0              0  27.32
# never              Male  28.0             0              0  27.32
# current          Female  36.0             0              0  23.45
# current            Male  76.0             1              1  20.14
# ...                 ...   ...           ...            ...    ...
# No Info          Female  80.0             0              0  27.32
# No Info          Female   2.0             0              0  17.37
# former             Male  66.0             0              0  27.83
# never            Female  24.0             0              0  35.42
# current          Female  57.0             0              0  22.43
#
#                  HbA1c_level  blood_glucose_level  diabetes
# smoking_history
# No Info                  6.6                   80         0
# No Info                  6.6                   80         0
# never                    5.7                  158         0
# current                  5.0                  155         0
# current                  4.8                  155         0
# ...                      ...                  ...       ...
# No Info                  6.2                   90         0
# No Info                  6.5                  100         0
# former                   5.7                  155         0
# never                    4.0                  100         0
# current                  6.6                   90         0
#
# [100000 rows x 8 columns]

# %%
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  54.0             0              0         No Info  27.32
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                   80         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
reindexed_df = diabetes_df.set_index("smoking_history")

# %%
reindexed_df.loc["never"]
# Out:
#                  gender   age  hypertension  heart_disease    bmi  \
# smoking_history
# never              Male  28.0             0              0  27.32
# never            Female  20.0             0              0  27.32
# never            Female  44.0             0              0  19.31
# never              Male  42.0             0              0  33.64
# never            Female  32.0             0              0  27.32
# ...                 ...   ...           ...            ...    ...
# never            Female  63.0             0              0  29.01
# never            Female  23.0             0              0  17.87
# never            Female  26.0             0              0  34.34
# never            Female  40.0             0              0  40.69
# never            Female  24.0             0              0  35.42
#
#                  HbA1c_level  blood_glucose_level  diabetes
# smoking_history
# never                    5.7                  158         0
# never                    6.6                   85         0
# never                    6.5                  200         1
# never                    4.8                  145         0
# never                    5.0                  100         0
# ...                      ...                  ...       ...
# never                    4.8                  145         0
# never                    5.8                  100         0
# never                    6.5                  160         0
# never                    3.5                  155         0
# never                    4.0                  100         0
#
# [35094 rows x 8 columns]

# %%
diabetes_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  54.0             0              0         No Info  27.32
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                   80         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %% [markdown]
# ### DataFrame, так само, можна комбінувати один з одним

# %%
us_video_csv_path = cwd / "youtube_trends/USvideos.csv"
us_cat_json_path = cwd / "youtube_trends/US_category_id.json"

# %%
gb_video_csv_path = cwd / "youtube_trends/GBvideos.csv"
gb_cat_json_path = cwd / "youtube_trends/GB_category_id.json"

# %%
us_video_df = pd.read_csv(us_video_csv_path)

# %%
gb_video_df = pd.read_csv(gb_video_csv_path)

# %%
gb_video_df.head(2)
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ      17.14.11      Taylor Swift: …Ready for It? (Live) - SNL
#
#          channel_title  category_id              publish_time  \
# 0           John Lewis           26  2017-11-10T07:38:29.000Z
# 1  Saturday Night Live           24  2017-11-12T06:24:44.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  1053632  25561
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...

# %%
gb_video_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  38916.000000  3.891600e+04  3.891600e+04  3.891600e+04   3.891600e+04
# mean      16.827937  5.911944e+06  1.345196e+05  7.612560e+03   1.308835e+04
# std        7.752728  1.900121e+07  3.499893e+05  5.095683e+04   5.066740e+04
# min        1.000000  8.510000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       10.000000  2.515272e+05  5.897000e+03  2.000000e+02   6.790000e+02
# 50%       20.000000  9.818890e+05  2.518250e+04  8.210000e+02   2.478000e+03
# 75%       24.000000  3.683628e+06  1.140892e+05  3.357500e+03   9.241500e+03
# max       43.000000  4.245389e+08  5.613827e+06  1.944971e+06   1.626501e+06

# %%
us_video_df.head(2)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
#
#                                                 tags    views  likes  \
# 0                                    SHANtell martin   748374  57527
# 1  last week tonight trump presidency|"last week ...  2418783  97185
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...

# %%
us_video_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
anglo_sax_df = pd.concat([gb_video_df, us_video_df])

# %%
anglo_sax_df.head(2)
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ      17.14.11      Taylor Swift: …Ready for It? (Live) - SNL
#
#          channel_title  category_id              publish_time  \
# 0           John Lewis           26  2017-11-10T07:38:29.000Z
# 1  Saturday Night Live           24  2017-11-12T06:24:44.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  1053632  25561
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...

# %%
anglo_sax_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  79865.000000  7.986500e+04  7.986500e+04  7.986500e+04   7.986500e+04
# mean      18.440205  4.091166e+06  1.036262e+05  5.612328e+03   1.070850e+04
# std        7.818304  1.439125e+07  2.957265e+05  4.124462e+04   4.443679e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       10.000000  2.464170e+05  5.642000e+03  2.010000e+02   6.420000e+02
# 50%       22.000000  7.961060e+05  2.092200e+04  7.120000e+02   2.099000e+03
# 75%       24.000000  2.535704e+06  7.824800e+04  2.527000e+03   7.220000e+03
# max       43.000000  4.245389e+08  5.613827e+06  1.944971e+06   1.626501e+06

# %%
us_cat_df = pd.read_json(us_cat_json_path)

# %%
us_cat_df.head(2)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
us_cat_df = pd.json_normalize(us_cat_df["items"])

# %%
us_cat_df = us_cat_df.rename(columns={"id": "category_id"})

# %%
us_video_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
us_cat_df.category_id = us_cat_df.category_id.astype("int64")

# %%
joined_df = pd.merge(us_video_df, us_cat_df, how="inner", on="category_id")

# %%
joined_df[(joined_df["category_id"] == 22) & (joined_df["snippet.assignable"])].head(2)
# Out:
#       video_id trending_date                               title  \
# 0  2kyS6SvSYSE      17.14.11  WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  0mlNzVSJrT0      17.14.11                Me-O Cats Commercial
#
#   channel_title  category_id              publish_time  \
# 0  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1       Nobrand           22  2017-04-21T06:47:32.000Z
#
#                         tags   views  likes  dislikes  ...  \
# 0            SHANtell martin  748374  57527      2966  ...
# 1  cute|"cats"|"thai"|"eggs"   98966   2486       184  ...
#
#                                    thumbnail_link comments_disabled  \
# 0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg             False
# 1  https://i.ytimg.com/vi/0mlNzVSJrT0/default.jpg             False
#
#    ratings_disabled  video_error_or_removed  \
# 0             False                   False
# 1             False                   False
#
#                                          description                   kind  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  youtube#videoCategory
# 1  Kittens come out of the eggs in a Thai commerc...  youtube#videoCategory
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
#
#           snippet.channelId   snippet.title snippet.assignable
# 0  UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# 1  UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Трансформації можуть бути доволі складними. Бажано планувати такі трансформації, щоб їх можна було описати через apply (це метод, котрий застосовує певну функцію на кожен рядок вашого DataFrame)

# %%
from datetime import datetime, timedelta

joined_df["parsed_date"] = joined_df["trending_date"].apply(lambda column_value: datetime.strptime(column_value, "%y.%d.%m"))

# %%
joined_df[joined_df["parsed_date"] - datetime(2017, 11, 14) < timedelta(days=2)].head(2)
# Out:
#       video_id trending_date                               title  \
# 0  2kyS6SvSYSE      17.14.11  WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  0mlNzVSJrT0      17.14.11                Me-O Cats Commercial
#
#   channel_title  category_id              publish_time  \
# 0  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1       Nobrand           22  2017-04-21T06:47:32.000Z
#
#                         tags   views  likes  dislikes  ...  comments_disabled  \
# 0            SHANtell martin  748374  57527      2966  ...              False
# 1  cute|"cats"|"thai"|"eggs"   98966   2486       184  ...              False
#
#   ratings_disabled  video_error_or_removed  \
# 0            False                   False
# 1            False                   False
#
#                                          description                   kind  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  youtube#videoCategory
# 1  Kittens come out of the eggs in a Thai commerc...  youtube#videoCategory
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
#
#           snippet.channelId   snippet.title snippet.assignable parsed_date
# 0  UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True  2017-11-14
# 1  UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True  2017-11-14
#
# [2 rows x 22 columns]

# %%
joined_df["parsed_tags"] = joined_df["tags"].apply(lambda col: col.split("|"))

# %%
joined_df.explode("parsed_tags")
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# ...            ...           ...
# 40948  V6ElE2xs48c      18.06.06
# 40948  V6ElE2xs48c      18.06.06
# 40948  V6ElE2xs48c      18.06.06
# 40948  V6ElE2xs48c      18.06.06
# 40948  V6ElE2xs48c      18.06.06
#
#                                               title    channel_title  \
# 0                WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1                              Me-O Cats Commercial          Nobrand
# 1                              Me-O Cats Commercial          Nobrand
# 1                              Me-O Cats Commercial          Nobrand
# 1                              Me-O Cats Commercial          Nobrand
# ...                                             ...              ...
# 40948  Game of Zones - S5:E5: The Isle of Van Gundy  Bleacher Report
# 40948  Game of Zones - S5:E5: The Isle of Van Gundy  Bleacher Report
# 40948  Game of Zones - S5:E5: The Isle of Van Gundy  Bleacher Report
# 40948  Game of Zones - S5:E5: The Isle of Van Gundy  Bleacher Report
# 40948  Game of Zones - S5:E5: The Isle of Van Gundy  Bleacher Report
#
#        category_id              publish_time  \
# 0               22  2017-11-13T17:13:01.000Z
# 1               22  2017-04-21T06:47:32.000Z
# 1               22  2017-04-21T06:47:32.000Z
# 1               22  2017-04-21T06:47:32.000Z
# 1               22  2017-04-21T06:47:32.000Z
# ...            ...                       ...
# 40948           43  2018-05-10T21:01:22.000Z
# 40948           43  2018-05-10T21:01:22.000Z
# 40948           43  2018-05-10T21:01:22.000Z
# 40948           43  2018-05-10T21:01:22.000Z
# 40948           43  2018-05-10T21:01:22.000Z
#
#                                                     tags    views  likes  \
# 0                                        SHANtell martin   748374  57527
# 1                              cute|"cats"|"thai"|"eggs"    98966   2486
# 1                              cute|"cats"|"thai"|"eggs"    98966   2486
# 1                              cute|"cats"|"thai"|"eggs"    98966   2486
# 1                              cute|"cats"|"thai"|"eggs"    98966   2486
# ...                                                  ...      ...    ...
# 40948  bleacher report|"br"|"nba"|"Stan Van Gundy"|"J...  1351321  22587
# 40948  bleacher report|"br"|"nba"|"Stan Van Gundy"|"J...  1351321  22587
# 40948  bleacher report|"br"|"nba"|"Stan Van Gundy"|"J...  1351321  22587
# 40948  bleacher report|"br"|"nba"|"Stan Van Gundy"|"J...  1351321  22587
# 40948  bleacher report|"br"|"nba"|"Stan Van Gundy"|"J...  1351321  22587
#
#        dislikes  ...  ratings_disabled video_error_or_removed  \
# 0          2966  ...             False                  False
# 1           184  ...             False                  False
# 1           184  ...             False                  False
# 1           184  ...             False                  False
# 1           184  ...             False                  False
# ...         ...  ...               ...                    ...
# 40948       616  ...             False                  False
# 40948       616  ...             False                  False
# 40948       616  ...             False                  False
# 40948       616  ...             False                  False
# 40948       616  ...             False                  False
#
#                                              description  \
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      Kittens come out of the eggs in a Thai commerc...
# 1      Kittens come out of the eggs in a Thai commerc...
# 1      Kittens come out of the eggs in a Thai commerc...
# 1      Kittens come out of the eggs in a Thai commerc...
# ...                                                  ...
# 40948  On an island full of Van Gundys, Stan gets tal...
# 40948  On an island full of Van Gundys, Stan gets tal...
# 40948  On an island full of Van Gundys, Stan gets tal...
# 40948  On an island full of Van Gundys, Stan gets tal...
# 40948  On an island full of Van Gundys, Stan gets tal...
#
#                         kind  \
# 0      youtube#videoCategory
# 1      youtube#videoCategory
# 1      youtube#videoCategory
# 1      youtube#videoCategory
# 1      youtube#videoCategory
# ...                      ...
# 40948  youtube#videoCategory
# 40948  youtube#videoCategory
# 40948  youtube#videoCategory
# 40948  youtube#videoCategory
# 40948  youtube#videoCategory
#
#                                                     etag  \
# 0      "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1      "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1      "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1      "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 1      "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# ...                                                  ...
# 40948  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
# 40948  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
# 40948  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
# 40948  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
# 40948  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
#
#               snippet.channelId   snippet.title snippet.assignable  \
# 0      UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# 1      UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# 1      UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# 1      UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# 1      UCBR8-60-B28hp2BmDPdntcQ  People & Blogs               True
# ...                         ...             ...                ...
# 40948  UCBR8-60-B28hp2BmDPdntcQ           Shows              False
# 40948  UCBR8-60-B28hp2BmDPdntcQ           Shows              False
# 40948  UCBR8-60-B28hp2BmDPdntcQ           Shows              False
# 40948  UCBR8-60-B28hp2BmDPdntcQ           Shows              False
# 40948  UCBR8-60-B28hp2BmDPdntcQ           Shows              False
#
#       parsed_date      parsed_tags
# 0      2017-11-14  SHANtell martin
# 1      2017-11-14             cute
# 1      2017-11-14           "cats"
# 1      2017-11-14           "thai"
# 1      2017-11-14           "eggs"
# ...           ...              ...
# 40948  2018-06-06       "playoffs"
# 40948  2018-06-06         "finals"
# 40948  2018-06-06         "lebron"
# 40948  2018-06-06          "curry"
# 40948  2018-06-06         "durant"
#
# [808183 rows x 23 columns]

# %% [markdown]
# ### Pandas дозволяє групувати дані між собою та рахувати ті чи інші функції агрегації. В Pandas це називається [split-apply-combine](https://pandas.pydata.org/docs/user_guide/groupby.html) процес

# %%
joined_df.groupby("category_id").sum()
# Out:
# /tmp/ipykernel_24806/3545196965.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   joined_df.groupby("category_id").sum()
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
# 19             343557084     4836246    340427         911511
# 20            2141218625    69038284   9184466       14740713
# 22            4917191726   186615999  10187901       24778032
# 23            5117426208   216346746   7230391       22545582
# 24           20604388195   530516491  42987663       73566498
# 25            1473765704    18151033   4180049        6039433
# 26            4078545064   162880075   5473899       23149550
# 27            1180629990    49257772   1351972        5442242
# 28            3487756816    82532638   4548402       11989926
# 29             168941392    14815646   3310381        4808797
# 43              51501058     1082639     24508          95117
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# category_id
# 1                           28                14                      13
# 2                            5                10                       0
# 10                           9                24                       0
# 15                           4                 0                       0
# 17                          28                17                       2
# 19                           0                 0                       0
# 20                           8                 0                       0
# 22                          66                37                       0
# 23                           2                 0                       0
# 24                         196                30                       8
# 25                         174                 1                       0
# 26                          11                11                       0
# 27                           8                 5                       0
# 28                          90                16                       0
# 29                           4                 4                       0
# 43                           0                 0                       0
#
#              snippet.assignable
# category_id
# 1                          2345
# 2                           384
# 10                         6472
# 15                          920
# 17                         2174
# 19                          402
# 20                          817
# 22                         3210
# 23                         3457
# 24                         9964
# 25                         2487
# 26                         4146
# 27                         1656
# 28                         2401
# 29                           57
# 43                            0
